# %% [markdown]
# # DraftKings URL
# http://rotoguru1.com/cgi-bin/byday.pl?game=dk&month=5&day=25&year=2019

# %% [markdown]
# # Fanduel URL
# http://rotoguru1.com/cgi-bin/byday.pl?game=fd&month=5&day=25&year=2019

# %% [markdown]
# # Import Packages

# %%
import pandas as pd
# from bs4 import BeautifulSoup
# import urllib

# %% [markdown]
# # Scrape Data

# %%
site = 'dk'
month = 5
day = 25
year = 2019
url = f'http://rotoguru1.com/cgi-bin/byday.pl?game={site}&month={month}&day={day}&year={year}'
# page = urllib.request.urlopen(url)
# soup = BeautifulSoup(page,'html')

# %%
# table = soup.find('table', id='daily')

# header = table.find('thead').text.split('\n')[3:-2]
# header = ['gl' if x=='' else x for x in header]
# header

# %%
test_df = pd.read_html(url, header=None, index_col = None)

# %%
len(test_df)
# Out:
# 5

# %%
test_df[3]
# Out:
#                                                      0  \
# 0                        Jump to: Pitchers | Hitters |
# 1                                             Pitchers
# 2                                                    P
# 3                                                    P
# 4                                                    P
# ..                                                 ...
# 450                                                NaN
# 451                                                  4
# 452                                                 46
# 453                                                NaN
# 454  For data in semi-colon delimited text format, ...
#
#                                                      1  \
# 0                        Jump to: Pitchers | Hitters |
# 1                                             Pitchers
# 2                                     Patrick Corbin^9
# 3                                     Charlie Morton^0
# ...

# %% [markdown]
# ## Drop first row

# %%
test_df_copy = test_df[3].copy()
test_df_copy = test_df_copy.drop([0])
test_df_copy
# Out:
#                                                      0  \
# 1                                             Pitchers
# 2                                                    P
# 3                                                    P
# 4                                                    P
# 5                                                    P
# ..                                                 ...
# 450                                                NaN
# 451                                                  4
# 452                                                 46
# 453                                                NaN
# 454  For data in semi-colon delimited text format, ...
#
#                                                      1  \
# 1                                             Pitchers
# 2                                     Patrick Corbin^9
# 3                                     Charlie Morton^0
# 4                                        Kyle Gibson^0
# ...

# %% [markdown]
# ## Drop Column 8

# %%
test_df_copy = test_df_copy.drop([8], axis = 1)
test_df_copy
# Out:
#                                                      0  \
# 1                                             Pitchers
# 2                                                    P
# 3                                                    P
# 4                                                    P
# 5                                                    P
# ..                                                 ...
# 450                                                NaN
# 451                                                  4
# 452                                                 46
# 453                                                NaN
# 454  For data in semi-colon delimited text format, ...
#
#                                                      1  \
# 1                                             Pitchers
# 2                                     Patrick Corbin^9
# 3                                     Charlie Morton^0
# 4                                        Kyle Gibson^0
# ...

# %% [markdown]
# ## Rename Header

# %%
test_df_copy = test_df_copy.rename(columns=test_df_copy.iloc[0])
test_df_copy
# Out:
#                                               Pitchers  \
# 1                                             Pitchers
# 2                                                    P
# 3                                                    P
# 4                                                    P
# 5                                                    P
# ..                                                 ...
# 450                                                NaN
# 451                                                  4
# 452                                                 46
# 453                                                NaN
# 454  For data in semi-colon delimited text format, ...
#
#                                               Pitchers  \
# 1                                             Pitchers
# 2                                     Patrick Corbin^9
# 3                                     Charlie Morton^0
# 4                                        Kyle Gibson^0
# ...

# %% [markdown]
# ## Rename First Column

# %%
test_df_copy.columns.values[0] = 'Position'
test_df_copy
# Out:
#                                               Position  \
# 1                                             Pitchers
# 2                                                    P
# 3                                                    P
# 4                                                    P
# 5                                                    P
# ..                                                 ...
# 450                                                NaN
# 451                                                  4
# 452                                                 46
# 453                                                NaN
# 454  For data in semi-colon delimited text format, ...
#
#                                               Pitchers  \
# 1                                             Pitchers
# 2                                     Patrick Corbin^9
# 3                                     Charlie Morton^0
# 4                                        Kyle Gibson^0
# ...

# %% [markdown]
# ## Drop First Row

# %%
test_df_copy = test_df_copy.drop([1])
test_df_copy
# Out:
#                                               Position  \
# 2                                                    P
# 3                                                    P
# 4                                                    P
# 5                                                    P
# 6                                                    P
# ..                                                 ...
# 450                                                NaN
# 451                                                  4
# 452                                                 46
# 453                                                NaN
# 454  For data in semi-colon delimited text format, ...
#
#                                               Pitchers  \
# 2                                     Patrick Corbin^9
# 3                                     Charlie Morton^0
# 4                                        Kyle Gibson^0
# 5                                       Jake Arrieta^9
# ...

# %% [markdown]
# ## Drop Last Row

# %%
test_df_copy.drop(test_df_copy.tail(1).index,inplace=True) # drop last n rows
test_df_copy
# Out:
#     Position          Pitchers Points   Salary Team      Opp. Score  \
# 2          P  Patrick Corbin^9  36.25  $11,500  WAS     v mia   5-0
# 3          P  Charlie Morton^0  31.90   $9,800  TAM     @ cle   6-2
# 4          P     Kyle Gibson^0  31.55   $8,500  MIN     v chw   8-1
# 5          P    Jake Arrieta^9  30.40   $7,500  PHI     @ mil   7-2
# 6          P      James Happ^0  29.10   $7,800  NYY  @ kan(1)   7-3
# ..       ...               ...    ...      ...  ...       ...   ...
# 449        3    Ryan O'Hearn^7   0.00   $3,400  KAN  v nyy(2)   5-6
# 450      NaN      Kyle Garlick   0.00      NaN  LAD     @ pit   7-2
# 451        4     Nicky Lopez^1   0.00   $3,600  KAN  v nyy(2)   5-6
# 452       46    Thairo Estrada   0.00   $3,600  NYY  @ kan(2)   6-5
# 453      NaN       Seby Zavala   0.00      NaN  CHW     @ min   1-8
#
#                     Stats Summary
# 2           9.0IP 4H BB 5K Win CG
# 3    6.0IP 3H R ER 2BB 10K HB Win
# 4      7.0IP 5H R ER BB 9K HB Win
# ...

# %% [markdown]
# # Remove the period from 'Opp.'

# %%
test_df_copy.columns.values[5] = 'Opp'
test_df_copy
# Out:
#     Position          Pitchers Points   Salary Team       Opp Score  \
# 2          P  Patrick Corbin^9  36.25  $11,500  WAS     v mia   5-0
# 3          P  Charlie Morton^0  31.90   $9,800  TAM     @ cle   6-2
# 4          P     Kyle Gibson^0  31.55   $8,500  MIN     v chw   8-1
# 5          P    Jake Arrieta^9  30.40   $7,500  PHI     @ mil   7-2
# 6          P      James Happ^0  29.10   $7,800  NYY  @ kan(1)   7-3
# ..       ...               ...    ...      ...  ...       ...   ...
# 449        3    Ryan O'Hearn^7   0.00   $3,400  KAN  v nyy(2)   5-6
# 450      NaN      Kyle Garlick   0.00      NaN  LAD     @ pit   7-2
# 451        4     Nicky Lopez^1   0.00   $3,600  KAN  v nyy(2)   5-6
# 452       46    Thairo Estrada   0.00   $3,600  NYY  @ kan(2)   6-5
# 453      NaN       Seby Zavala   0.00      NaN  CHW     @ min   1-8
#
#                     Stats Summary
# 2           9.0IP 4H BB 5K Win CG
# 3    6.0IP 3H R ER 2BB 10K HB Win
# 4      7.0IP 5H R ER BB 9K HB Win
# ...

# %% [markdown]
# # Change Pitcher to Player

# %%
test_df_copy.columns.values[1] = 'Player'
test_df_copy
# Out:
#     Position            Player Points   Salary Team       Opp Score  \
# 2          P  Patrick Corbin^9  36.25  $11,500  WAS     v mia   5-0
# 3          P  Charlie Morton^0  31.90   $9,800  TAM     @ cle   6-2
# 4          P     Kyle Gibson^0  31.55   $8,500  MIN     v chw   8-1
# 5          P    Jake Arrieta^9  30.40   $7,500  PHI     @ mil   7-2
# 6          P      James Happ^0  29.10   $7,800  NYY  @ kan(1)   7-3
# ..       ...               ...    ...      ...  ...       ...   ...
# 449        3    Ryan O'Hearn^7   0.00   $3,400  KAN  v nyy(2)   5-6
# 450      NaN      Kyle Garlick   0.00      NaN  LAD     @ pit   7-2
# 451        4     Nicky Lopez^1   0.00   $3,600  KAN  v nyy(2)   5-6
# 452       46    Thairo Estrada   0.00   $3,600  NYY  @ kan(2)   6-5
# 453      NaN       Seby Zavala   0.00      NaN  CHW     @ min   1-8
#
#                     Stats Summary
# 2           9.0IP 4H BB 5K Win CG
# 3    6.0IP 3H R ER 2BB 10K HB Win
# 4      7.0IP 5H R ER BB 9K HB Win
# ...

# %%
test_df_copy.columns.values
# Out:
# array(['Position', 'Player', 'Points', 'Salary', 'Team', 'Opp', 'Score',
#        'Stats Summary'], dtype=object)

# %%
test_df_copy.loc[125:135, :]
# Out:
#                           Position                         Player  \
# 125                              P                   Scott Barlow
# 126                              P                 Daniel Winkler
# 127                              P                Edwin Jackson^0
# 128                              P                Kyle Freeland^9
# 129                              P                Andrew Suarez^9
# 130                              P                  Jorge Lopez^0
# 131                              P                   Sam Gaviglio
# 132  Jump to: Pitchers | Hitters |  Jump to: Pitchers | Hitters |
# 133                        Hitters                        Hitters
# 134                              7               Hunter Renfroe^5
# 135                             37                    Wil Myers^7
#
#                             Points                         Salary  \
# 125                          -6.00                         $4,000
# ...

# %% [markdown]
# # Need to find where the "Jump to: ..." is

# %%
patternDel = "Jump to:"
filterPattern = test_df_copy['Position'].str.contains(patternDel)

# %%
test_df_copy.loc[filterPattern==True,:]
# Out:
#                           Position                         Player  \
# 132  Jump to: Pitchers | Hitters |  Jump to: Pitchers | Hitters |
#
#                             Points                         Salary  \
# 132  Jump to: Pitchers | Hitters |  Jump to: Pitchers | Hitters |
#
#                               Team                            Opp  \
# 132  Jump to: Pitchers | Hitters |  Jump to: Pitchers | Hitters |
#
#                              Score Stats Summary
# 132  Jump to: Pitchers | Hitters |           NaN

# %%
test_df_copy.loc[132,:]
# Out:
# Position         Jump to: Pitchers | Hitters |
# Player           Jump to: Pitchers | Hitters |
# Points           Jump to: Pitchers | Hitters |
# Salary           Jump to: Pitchers | Hitters |
# Team             Jump to: Pitchers | Hitters |
# Opp              Jump to: Pitchers | Hitters |
# Score            Jump to: Pitchers | Hitters |
# Stats Summary                              NaN
# Name: 132, dtype: object

# %%
test_df_copy = test_df_copy.loc[filterPattern!=True,:]

# %%
test_df_copy.loc[130:135,:]
# Out:
#     Position            Player  Points  Salary  Team       Opp  Score  \
# 130        P     Jorge Lopez^0   -9.95  $5,000   KAN  v nyy(2)    5-6
# 131        P      Sam Gaviglio  -10.70  $6,800   TOR     v sdg   4-19
# 133  Hitters           Hitters  Points  Salary  Team      Opp.  Score
# 134        7  Hunter Renfroe^5   45.00  $4,400   SDG     @ tor   19-4
# 135       37       Wil Myers^7   44.00  $3,800   SDG     @ tor   19-4
#
#                  Stats Summary
# 130  1.0IP 6H 5R 5ER BB K Loss
# 131       0.2IP 6H 5R 5ER BB K
# 133              Stats Summary
# 134      4/6 4R 3RBI 2HR SO SB
# 135    2/2 4R 4RBI 2HR 3BB HBP

# %%
test_df_copy = test_df_copy.reset_index()
test_df_copy.loc[130:135,:]
# Out:
#      index Position            Player  Points  Salary  Team    Opp     Score  \
# 130    133  Hitters           Hitters  Points  Salary  Team   Opp.     Score
# 131    134        7  Hunter Renfroe^5   45.00  $4,400   SDG  @ tor      19-4
# 132    135       37       Wil Myers^7   44.00  $3,800   SDG  @ tor      19-4
# 133    136        2    Wilson Ramos^4   37.00  $4,200   NYM  v det  5-4(F13)
# 134    137        3    Rhys Hoskins^4   33.00  $4,800   PHI  @ mil       7-2
# 135    138        5   Nolan Arenado^4   30.00  $5,600   COL  v bal       6-9
#
#                Stats Summary
# 130            Stats Summary
# 131    4/6 4R 3RBI 2HR SO SB
# 132  2/2 4R 4RBI 2HR 3BB HBP
# 133       3/4 2R 4RBI 2HR BB
# 134  3/4 2R 2RBI 2B HR BB SB
# 135         3/4 R 5RBI 2B HR

# %%
test_df_copy = test_df_copy.drop(['index'], axis = 1)
test_df_copy.head()
# Out:
#   Position            Player Points   Salary Team       Opp Score  \
# 0        P  Patrick Corbin^9  36.25  $11,500  WAS     v mia   5-0
# 1        P  Charlie Morton^0  31.90   $9,800  TAM     @ cle   6-2
# 2        P     Kyle Gibson^0  31.55   $8,500  MIN     v chw   8-1
# 3        P    Jake Arrieta^9  30.40   $7,500  PHI     @ mil   7-2
# 4        P      James Happ^0  29.10   $7,800  NYY  @ kan(1)   7-3
#
#                   Stats Summary
# 0         9.0IP 4H BB 5K Win CG
# 1  6.0IP 3H R ER 2BB 10K HB Win
# 2    7.0IP 5H R ER BB 9K HB Win
# 3     8.0IP 5H 2R 2ER BB 8K Win
# 4       6.0IP 4H 3R 3ER 10K Win

# %% [markdown]
# # Remove where it says "Hitter" for Position

# %%
patternDel = "Hitter"
filterPattern = test_df_copy['Position'].str.contains(patternDel)

# %%
test_df_copy.loc[filterPattern==True,:]
# Out:
#     Position   Player  Points  Salary  Team   Opp  Score  Stats Summary
# 130  Hitters  Hitters  Points  Salary  Team  Opp.  Score  Stats Summary

# %%
test_df_copy.loc[130,:]
# Out:
# Position               Hitters
# Player                 Hitters
# Points                  Points
# Salary                  Salary
# Team                      Team
# Opp                       Opp.
# Score                    Score
# Stats Summary    Stats Summary
# Name: 130, dtype: object

# %%
test_df_copy = test_df_copy.loc[filterPattern!=True,:]

# %%
test_df_copy.loc[129:145,:]
# Out:
#     Position             Player  Points  Salary Team    Opp     Score  \
# 129        P       Sam Gaviglio  -10.70  $6,800  TOR  v sdg      4-19
# 131        7   Hunter Renfroe^5   45.00  $4,400  SDG  @ tor      19-4
# 132       37        Wil Myers^7   44.00  $3,800  SDG  @ tor      19-4
# 133        2     Wilson Ramos^4   37.00  $4,200  NYM  v det  5-4(F13)
# 134        3     Rhys Hoskins^4   33.00  $4,800  PHI  @ mil       7-2
# 135        5    Nolan Arenado^4   30.00  $5,600  COL  v bal       6-9
# 136       46  Jonathan Villar^2   28.00  $4,700  BAL  @ col       9-6
# 137        7  Domingo Santana^5   28.00  $3,900  SEA  @ oak       5-6
# 138        7     Kole Calhoun^7   28.00  $3,600  LAA  v tex       3-2
# 139       47      Ketel Marte^1   26.00  $4,600  ARI  @ sfo      10-4
# 140       45   Ehire Adrianza^8   26.00  $3,600  MIN  v chw       8-1
# 141        4      Ian Kinsler^8   26.00  $3,100  SDG  @ tor      19-4
# ...

# %%
test_df_copy = test_df_copy.reset_index()
test_df_copy.loc[130:135,:]
# Out:
#      index Position             Player Points  Salary Team    Opp     Score  \
# 130    131        7   Hunter Renfroe^5  45.00  $4,400  SDG  @ tor      19-4
# 131    132       37        Wil Myers^7  44.00  $3,800  SDG  @ tor      19-4
# 132    133        2     Wilson Ramos^4  37.00  $4,200  NYM  v det  5-4(F13)
# 133    134        3     Rhys Hoskins^4  33.00  $4,800  PHI  @ mil       7-2
# 134    135        5    Nolan Arenado^4  30.00  $5,600  COL  v bal       6-9
# 135    136       46  Jonathan Villar^2  28.00  $4,700  BAL  @ col       9-6
#
#                Stats Summary
# 130    4/6 4R 3RBI 2HR SO SB
# 131  2/2 4R 4RBI 2HR 3BB HBP
# 132       3/4 2R 4RBI 2HR BB
# 133  3/4 2R 2RBI 2B HR BB SB
# 134         3/4 R 5RBI 2B HR
# 135     3/5 2R 3RBI 2B HR SO

# %%
test_df_copy = test_df_copy.drop(['index'], axis = 1)
test_df_copy.head()
# Out:
#   Position            Player Points   Salary Team       Opp Score  \
# 0        P  Patrick Corbin^9  36.25  $11,500  WAS     v mia   5-0
# 1        P  Charlie Morton^0  31.90   $9,800  TAM     @ cle   6-2
# 2        P     Kyle Gibson^0  31.55   $8,500  MIN     v chw   8-1
# 3        P    Jake Arrieta^9  30.40   $7,500  PHI     @ mil   7-2
# 4        P      James Happ^0  29.10   $7,800  NYY  @ kan(1)   7-3
#
#                   Stats Summary
# 0         9.0IP 4H BB 5K Win CG
# 1  6.0IP 3H R ER 2BB 10K HB Win
# 2    7.0IP 5H R ER BB 9K HB Win
# 3     8.0IP 5H 2R 2ER BB 8K Win
# 4       6.0IP 4H 3R 3ER 10K Win

# %% [markdown]
# # Change Dtype of columns

# %%
test_df_copy.head()
# Out:
#   Position            Player Points   Salary Team       Opp Score  \
# 2        P  Patrick Corbin^9  36.25  $11,500  WAS     v mia   5-0
# 3        P  Charlie Morton^0  31.90   $9,800  TAM     @ cle   6-2
# 4        P     Kyle Gibson^0  31.55   $8,500  MIN     v chw   8-1
# 5        P    Jake Arrieta^9  30.40   $7,500  PHI     @ mil   7-2
# 6        P      James Happ^0  29.10   $7,800  NYY  @ kan(1)   7-3
#
#                   Stats Summary
# 2         9.0IP 4H BB 5K Win CG
# 3  6.0IP 3H R ER 2BB 10K HB Win
# 4    7.0IP 5H R ER BB 9K HB Win
# 5     8.0IP 5H 2R 2ER BB 8K Win
# 6       6.0IP 4H 3R 3ER 10K Win

# %%
test_df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 452 entries, 2 to 453
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Position       446 non-null    object
#  1   Player         452 non-null    object
#  2   Points         452 non-null    object
#  3   Salary         446 non-null    object
#  4   Team           452 non-null    object
#  5   Opp            452 non-null    object
#  6   Score          452 non-null    object
#  7   Stats Summary  447 non-null    object
# dtypes: object(8)
# memory usage: 51.8+ KB

# %%
test_df_copy = test_df_copy.astype({'Points':'float64'})

# %%
test_df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Position       444 non-null    object
#  1   Player         450 non-null    object
#  2   Points         450 non-null    float64
#  3   Salary         444 non-null    object
#  4   Team           450 non-null    object
#  5   Opp            450 non-null    object
#  6   Score          450 non-null    object
#  7   Stats Summary  446 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 28.2+ KB

# %%
test_df_copy.head()
# Out:
#   Position            Player  Points   Salary Team       Opp Score  \
# 0        P  Patrick Corbin^9   36.25  $11,500  WAS     v mia   5-0
# 1        P  Charlie Morton^0   31.90   $9,800  TAM     @ cle   6-2
# 2        P     Kyle Gibson^0   31.55   $8,500  MIN     v chw   8-1
# 3        P    Jake Arrieta^9   30.40   $7,500  PHI     @ mil   7-2
# 4        P      James Happ^0   29.10   $7,800  NYY  @ kan(1)   7-3
#
#                   Stats Summary
# 0         9.0IP 4H BB 5K Win CG
# 1  6.0IP 3H R ER 2BB 10K HB Win
# 2    7.0IP 5H R ER BB 9K HB Win
# 3     8.0IP 5H 2R 2ER BB 8K Win
# 4       6.0IP 4H 3R 3ER 10K Win

# %% [markdown]
# ## Remove the position after the '^' and place in batting order
#
# Need to use some logic to find everything after the 'v'

# %%
test_df_copy.loc[127, 'Player'].split('^',2)
# Out:
# ['Edwin Jackson', '0']

# %%
split_player_bat_order = test_df_copy.Player.str.split('^', expand = True)
split_player_bat_order.rename(columns = {0: 'Player_split', 1:'Batting Order'}, inplace = True)
split_player_bat_order.head()
# Out:
#      Player_split Batting Order
# 0  Patrick Corbin             9
# 1  Charlie Morton             0
# 2     Kyle Gibson             0
# 3    Jake Arrieta             9
# 4      James Happ             0

# %%
test_df_copy = test_df_copy.join(split_player_bat_order)
test_df_copy.head()
# Out:
#   Position            Player  Points   Salary Team       Opp Score  \
# 0        P  Patrick Corbin^9   36.25  $11,500  WAS     v mia   5-0
# 1        P  Charlie Morton^0   31.90   $9,800  TAM     @ cle   6-2
# 2        P     Kyle Gibson^0   31.55   $8,500  MIN     v chw   8-1
# 3        P    Jake Arrieta^9   30.40   $7,500  PHI     @ mil   7-2
# 4        P      James Happ^0   29.10   $7,800  NYY  @ kan(1)   7-3
#
#                   Stats Summary    Player_split Batting Order
# 0         9.0IP 4H BB 5K Win CG  Patrick Corbin             9
# 1  6.0IP 3H R ER 2BB 10K HB Win  Charlie Morton             0
# 2    7.0IP 5H R ER BB 9K HB Win     Kyle Gibson             0
# 3     8.0IP 5H 2R 2ER BB 8K Win    Jake Arrieta             9
# 4       6.0IP 4H 3R 3ER 10K Win      James Happ             0

# %% [markdown]
# # Drop Player and rename Player_split to Player

# %%
test_df_copy = test_df_copy.drop(['Player'], axis = 1)
test_df_copy.head()
# Out:
#   Position  Points   Salary Team       Opp Score  \
# 0        P   36.25  $11,500  WAS     v mia   5-0
# 1        P   31.90   $9,800  TAM     @ cle   6-2
# 2        P   31.55   $8,500  MIN     v chw   8-1
# 3        P   30.40   $7,500  PHI     @ mil   7-2
# 4        P   29.10   $7,800  NYY  @ kan(1)   7-3
#
#                   Stats Summary    Player_split Batting Order
# 0         9.0IP 4H BB 5K Win CG  Patrick Corbin             9
# 1  6.0IP 3H R ER 2BB 10K HB Win  Charlie Morton             0
# 2    7.0IP 5H R ER BB 9K HB Win     Kyle Gibson             0
# 3     8.0IP 5H 2R 2ER BB 8K Win    Jake Arrieta             9
# 4       6.0IP 4H 3R 3ER 10K Win      James Happ             0

# %%
test_df_copy.columns.values[test_df_copy.columns.values == 'Player_split'] = 'Player'
test_df_copy.columns.values
# Out:
# array(['Position', 'Points', 'Salary', 'Team', 'Opp', 'Score',
#        'Stats Summary', 'Player', 'Batting Order'], dtype=object)

# %%
test_df_copy.head()
# Out:
#   Position  Points   Salary Team       Opp Score  \
# 0        P   36.25  $11,500  WAS     v mia   5-0
# 1        P   31.90   $9,800  TAM     @ cle   6-2
# 2        P   31.55   $8,500  MIN     v chw   8-1
# 3        P   30.40   $7,500  PHI     @ mil   7-2
# 4        P   29.10   $7,800  NYY  @ kan(1)   7-3
#
#                   Stats Summary          Player Batting Order
# 0         9.0IP 4H BB 5K Win CG  Patrick Corbin             9
# 1  6.0IP 3H R ER 2BB 10K HB Win  Charlie Morton             0
# 2    7.0IP 5H R ER BB 9K HB Win     Kyle Gibson             0
# 3     8.0IP 5H 2R 2ER BB 8K Win    Jake Arrieta             9
# 4       6.0IP 4H 3R 3ER 10K Win      James Happ             0

# %% [markdown]
# # Add Home Dummy Variable
#
# Need some sort of if statment to see if Opp. has a 'v' or a '@'

# %%
patternDel = "v"
filterPattern = test_df_copy['Opp'].str.contains(patternDel)
filterPattern
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 445     True
# 446    False
# 447     True
# 448    False
# 449    False
# Name: Opp, Length: 450, dtype: bool

# %%
test_df_copy['Home'] = 0
test_df_copy.head()
# Out:
#   Position  Points   Salary Team       Opp Score  \
# 0        P   36.25  $11,500  WAS     v mia   5-0
# 1        P   31.90   $9,800  TAM     @ cle   6-2
# 2        P   31.55   $8,500  MIN     v chw   8-1
# 3        P   30.40   $7,500  PHI     @ mil   7-2
# 4        P   29.10   $7,800  NYY  @ kan(1)   7-3
#
#                   Stats Summary          Player Batting Order  Home
# 0         9.0IP 4H BB 5K Win CG  Patrick Corbin             9     0
# 1  6.0IP 3H R ER 2BB 10K HB Win  Charlie Morton             0     0
# 2    7.0IP 5H R ER BB 9K HB Win     Kyle Gibson             0     0
# 3     8.0IP 5H 2R 2ER BB 8K Win    Jake Arrieta             9     0
# 4       6.0IP 4H 3R 3ER 10K Win      James Happ             0     0

# %%
test_df_copy.loc[filterPattern==True, ['Home']] = 1
test_df_copy.head()
# Out:
#   Position  Points   Salary Team       Opp Score  \
# 0        P   36.25  $11,500  WAS     v mia   5-0
# 1        P   31.90   $9,800  TAM     @ cle   6-2
# 2        P   31.55   $8,500  MIN     v chw   8-1
# 3        P   30.40   $7,500  PHI     @ mil   7-2
# 4        P   29.10   $7,800  NYY  @ kan(1)   7-3
#
#                   Stats Summary          Player Batting Order  Home
# 0         9.0IP 4H BB 5K Win CG  Patrick Corbin             9     1
# 1  6.0IP 3H R ER 2BB 10K HB Win  Charlie Morton             0     0
# 2    7.0IP 5H R ER BB 9K HB Win     Kyle Gibson             0     1
# 3     8.0IP 5H 2R 2ER BB 8K Win    Jake Arrieta             9     0
# 4       6.0IP 4H 3R 3ER 10K Win      James Happ             0     0

# %% [markdown]
# # Double Header Dummy Variable

# %%
patternDel = "(2)"
filterPattern = test_df_copy['Opp'].str.contains(patternDel)

test_df_copy['Double Header'] = 0

test_df_copy.loc[filterPattern==True, ['Double Header']] = 1
test_df_copy.head()
# Out:
# C:\Users\Nicholas\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\strings.py:1952: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#   Position  Points   Salary Team       Opp Score  \
# 0        P   36.25  $11,500  WAS     v mia   5-0
# 1        P   31.90   $9,800  TAM     @ cle   6-2
# 2        P   31.55   $8,500  MIN     v chw   8-1
# 3        P   30.40   $7,500  PHI     @ mil   7-2
# 4        P   29.10   $7,800  NYY  @ kan(1)   7-3
#
#                   Stats Summary          Player Batting Order  Home  \
# 0         9.0IP 4H BB 5K Win CG  Patrick Corbin             9     1
# 1  6.0IP 3H R ER 2BB 10K HB Win  Charlie Morton             0     0
# 2    7.0IP 5H R ER BB 9K HB Win     Kyle Gibson             0     1
# 3     8.0IP 5H 2R 2ER BB 8K Win    Jake Arrieta             9     0
# 4       6.0IP 4H 3R 3ER 10K Win      James Happ             0     0
#
#    Double Header
# ...

# %%
test_df_copy.loc[test_df_copy['Double Header'] == 1, :].head()
# Out:
#    Position  Points  Salary Team       Opp Score              Stats Summary  \
# 24        P    9.40  $6,900  NYY  @ kan(2)   6-5  4.0IP 5H 3R 3ER BB 3K Win
# 31        P    7.15  $4,000  KAN  v nyy(2)   5-6                 1.2IP H 2K
# 40        P    6.25  $4,000  KAN  v nyy(2)   5-6                   1.0IP 2K
# 61        P    4.25  $5,100  NYY  @ kan(2)   6-5               1.0IP K Hold
# 62        P    4.25  $4,100  NYY  @ kan(2)   6-5               1.0IP K Hold
#
#              Player Batting Order  Home  Double Header
# 24     Chance Adams          None     0              1
# 31   Kevin McCarthy          None     1              1
# 40     Jake Diekman          None     1              1
# 61     Tommy Kahnle          None     0              1
# 62  Jonathan Holder          None     0              1

# %% [markdown]
# # Make a Pos 1 and Pos 2 for the hitters

# %% [markdown]
# # Need to map name to stats

# %% [markdown]
# # Move to Database
